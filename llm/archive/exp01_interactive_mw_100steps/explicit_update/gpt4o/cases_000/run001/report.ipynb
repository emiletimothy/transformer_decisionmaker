# %% [markdown]
# # Report: cases_000 / gpt4o_explicit_update_cases_000_run001

# %%
import sys, json
sys.path.insert(0, '/home/jupyter-xcao/mwu')
from mw_lib import (
    load_data, get_case,
    check_weight_normalization, analyze_model_output,
    plot_regret_comparison, plot_weight_comparison,
)
# %matplotlib inline

result       = json.load(open('/home/jupyter-xcao/mwu/results/interactive_api/gpt4o_explicit_update/cases_000/gpt4o_explicit_update_cases_000_run001/result.json'))
model_output = result['response']
inp          = result['input']

# reconstruct case for plot functions
data = load_data('/home/jupyter-xcao/mwu/mw_dataset.json')
case = get_case(data, 'cases', 0)

# %% [markdown]
# ## Case Info

# %%
print(f"split      : {result['meta']['split']}")
print(f"case index : {result['meta']['idx']}")
print(f"run        : {result['meta']['run']}")
print(f"mode       : {result['meta'].get('mode', 'manual')}")
print(f"n_steps    : {inp['T']}")
print(f"n_experts  : {inp['n']}")
print(f"eta        : {inp['eta']:.6f}")

# %% [markdown]
# ## Weight Normalization

# %%
norm = check_weight_normalization(model_output)
print('All normalized :', norm['all_normalized'])
print('Max deviation  :', f"{norm['max_deviation']:.2e}")
if norm['bad_steps']:
    print('Bad steps      :', norm['bad_steps'][:10])

# %% [markdown]
# ## Correctness Summary

# %%
w = result['analysis']['weights']
p = result['analysis']['mixture_probabilities']
y = result['analysis']['algorithm_predictions']

print(f"weights.check_norm    : {w['check_norm']}")
print(f"weights.mean_ell1     : {w['mean_ell1']:.4f}  std={w['std_ell1']:.4f}")
print()
print(f"prob.check_compute    : {p['check_compute']}")
print(f"prob.mean_abs_error   : {p['mean_abs_error']:.4f}  std={p['std_abs_error']:.4f}")
print()
print(f"pred.check_pred       : {y['check_pred']}")
print(f"pred.accuracy         : {y['accuracy']:.3f}")

# %% [markdown]
# ## Regret Comparison

# %%
plot_regret_comparison(case, model_output)

# %% [markdown]
# ## Weight Comparison

# %%
plot_weight_comparison(case, model_output)
